# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/Webscraping-with-Pandas/blob/main/Web_Scraping_NBA_Players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Web Scraping

# %%
year = '2019'
url = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'.format(year)
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'

# %%
years = [2015,2016,2017,2018,2019,2020]
link = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'

for year in years:
  url = link.format(year)
  print(url)
# Out:
# https://www.basketball-reference.com/leagues/NBA_2015_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2016_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2017_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2018_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2019_per_game.html
# https://www.basketball-reference.com/leagues/NBA_2020_per_game.html

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'

# %%
data = pd.read_html(url, header = 0)
data
# Out:
# [      Rk                    Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  \
#  0      1              Steven Adams   C  26  OKC  63  63  26.7  4.5   7.6  ...
#  1      2               Bam Adebayo  PF  22  MIA  72  72  33.6  6.1  11.0  ...
#  2      3         LaMarcus Aldridge   C  34  SAS  53  53  33.1  7.4  15.0  ...
#  3      4            Kyle Alexander   C  23  MIA   2   0   6.5  0.5   1.0  ...
#  4      5  Nickeil Alexander-Walker  SG  21  NOP  47   1  12.6  2.1   5.7  ...
#  ..   ...                       ...  ..  ..  ...  ..  ..   ...  ...   ...  ...
#  672  525                Trae Young  PG  21  ATL  60  60  35.3  9.1  20.8  ...
#  673  526               Cody Zeller   C  27  CHO  58  39  23.1  4.3   8.3  ...
#  674  527              Tyler Zeller   C  30  SAS   2   0   2.0  0.5   2.0  ...
#  675  528                Ante Žižić   C  23  CLE  22   0  10.0  1.9   3.3  ...
#  676  529               Ivica Zubac   C  22  LAC  72  70  18.4  3.3   5.3  ...
#
# ...

# %%
data[0][22:24]
# Out:
#     Rk         Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 22  Rk         Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB
# 23  21  Deandre Ayton    C   21  PHO  38  32  32.5  8.2  14.9  ...  .753  3.9
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 22  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 23  7.6  11.5  1.9  0.7  1.5  2.1  3.1  18.2
#
# [2 rows x 30 columns]

# %% [markdown]
# #Cleaning Data

# %%
dataset = data[0]

# %%
dataset[dataset.Age == 'Age']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 22   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 53   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 76   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 101  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 130  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 163  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 192  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 219  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 242  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 271  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 296  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
dataset[dataset.G == 'G']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 22   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 53   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 76   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 101  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 130  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 163  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 192  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 219  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 242  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 271  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 296  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
dataset = dataset.drop(dataset[dataset.Age == 'Age'].index)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 651 entries, 0 to 676
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      651 non-null    object
#  1   Player  651 non-null    object
#  2   Pos     651 non-null    object
#  3   Age     651 non-null    object
#  4   Tm      651 non-null    object
#  5   G       651 non-null    object
#  6   GS      651 non-null    object
#  7   MP      651 non-null    object
#  8   FG      651 non-null    object
#  9   FGA     651 non-null    object
#  10  FG%     649 non-null    object
#  11  3P      651 non-null    object
#  12  3PA     651 non-null    object
#  13  3P%     616 non-null    object
#  14  2P      651 non-null    object
#  15  2PA     651 non-null    object
#  16  2P%     645 non-null    object
#  17  eFG%    649 non-null    object
#  18  FT      651 non-null    object
#  19  FTA     651 non-null    object
#  20  FT%     618 non-null    object
# ...

# %%
dataset = dataset.drop(['Player', 'Pos', 'Tm'], axis = 1)

# %%
for col in dataset.columns:
        # Use try-except to catch any errors that occur when converting the data type
        try:
            dataset[col] = dataset[col].astype(float)
        except ValueError:
            # If the data type cannot be converted to int, print an error message
            print(f"Unable to convert {col} to int")

# %%
dataset.corr()['PTS'].sort_values()
# Out:
# Rk      0.012064
# Age     0.111290
# 2P%     0.120106
# FG%     0.211783
# FT%     0.244136
# eFG%    0.262080
# 3P%     0.262948
# BLK     0.347116
# ORB     0.362488
# G       0.514799
# PF      0.596922
# STL     0.617227
# TRB     0.627422
# DRB     0.684398
# GS      0.706195
# 3P      0.723893
# 3PA     0.728147
# AST     0.732807
# TOV     0.854511
# MP      0.881214
# FTA     0.882504
# FT      0.889070
# 2P      0.889503
# 2PA     0.910443
# FGA     0.982872
# FG      0.988500
# PTS     1.000000
# Name: PTS, dtype: float64

# %% [markdown]
# #Data Visualize

# %%
sns.histplot(dataset['PTS'], kde = True)
# Out:
# <Axes: xlabel='PTS', ylabel='Count'>

# %% [markdown]
# #Insights:
# - Players most likely to have 5 point in NBA Season 2020
